# %% [markdown]
# como eu faço para interagir com o site ?

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import webdriver_manager.chrome

servico = Service(ChromeDriverManager().install())

from selenium import webdriver
from selenium.webdriver.common.by import By
nav = webdriver.Chrome()
nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")

# %%
from selenium import webdriver

nav = webdriver.Chrome()

arquivo = "file:///C:/Users/55159/teste_sel/Arquivos/Pagina%20Hashtag.html"

nav.get(arquivo)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       3 navegador = webdriver.Chrome()
#       5 arquivo = "file:///C:/Users/55159/teste_sel/Arquivos/Pagina%20Hashtag.html"
# ----> 7 navegador.get(arquivo)
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:470, in WebDriver.get(self, url)
#     457 def get(self, url: str) -> None:
#     458     """Navigate the browser to the specified URL.
#     459
#     460     The method does not return until the page is fully loaded (i.e. the
#    (...)    468         `driver.get("https://example.com")`
#     469     """
# --> 470     self.execute(Command.GET, {"url": url})
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:447, in WebDriver.execute(self, driver_command, params)
#     444     elif "sessionId" not in params:
# ...

# %% [markdown]
# primeiro metodo de seleção "id"
# navegador.find_element -> um item apenas
# navegador.find_elements -> me da como resposta uma lista

# %%
from selenium.webdriver.common.by import By

titulo = nav.find_element(By.TAG_NAME, "h1")

print(titulo.text)
# Out:
# Conheça todos os Cursos da Hashtag Treinamentos

# %%
from selenium import webdriver
nav = webdriver.Chrome()
nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")
from selenium.webdriver.common.by import By

nav.find_element(By.ID,"firstname").send_keys("joao")
nav.find_element(By.ID,"email").send_keys("gomesjoao@gmail.com")
nav.find_element(By.ID,"_form_178_submit").click()

# %% [markdown]
# usando A CLASSE DO ELEMENTO

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
nav = webdriver.Chrome()
nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")
nav.find_element(By.CLASS_NAME, 'header__logo').click()

# %% [markdown]
# com XPATH

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
nav = webdriver.Chrome()
nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")
nav.find_element(By.XPATH, '//*[@id="excel"]/header/div/a').click()

# %% [markdown]
# selecionar pela tag

# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# nav = webdriver.Chrome()
# nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")
titulo = nav.find_element(By.TAG_NAME, 'h1').text
print(titulo)
# Out:
# Curso de Excel
# do básico ao avançado

# %% [markdown]
# selecionar pelo partial link text (ou LINK_TEXT)

# %%
# quero conseguir pegar o número de wpp de contato

# nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")
numero_wpp = nav.find_element(By.PARTIAL_LINK_TEXT, 'HashTag').text
print(numero_wpp)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[23], line 4
#       1 # quero conseguir pegar o número de wpp de contato
#       2
#       3 # nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")
# ----> 4 numero_wpp = nav.find_element(By.PARTIAL_LINK_TEXT, 'HashTag').text
#       5 print(numero_wpp)
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:823, in WebDriver.find_element(self, by, value)
#     820         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     821     return elements[0]
# --> 823 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:450, in WebDriver.execute(self, driver_command, params)
# ...

# %% [markdown]
# método email

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
nav = webdriver.Chrome()
nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")
nav.find_element(By.NAME, 'email').send_keys('gomesjoao2003@gmail.com')

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
nav = webdriver.Chrome()
nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")
nav.find_element(By.CLASS_NAME, 'header__titulo').click()
# print(nav)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[20], line 5
#       3 nav = webdriver.Chrome()
#       4 nav.get("https://www.hashtagtreinamentos.com/curso-de-excel-online")
# ----> 5 nav.find_element(By.CLASS_NAME, 'header__titulo').click()
#       6 # print(nav)
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:114, in WebElement.click(self)
#     107 def click(self) -> None:
#     108     """Clicks the element.
#     109
#     110     Example:
#     111         element = driver.find_element(By.ID, "foo")
#     112         element.click()
#     113     """
# --> 114     self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:508, in WebElement._execute(self, command, params)
#     506     params = {}
#     507 params["id"] = self._id
# ...
