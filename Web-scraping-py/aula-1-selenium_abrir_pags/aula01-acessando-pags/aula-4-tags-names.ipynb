# %% [markdown]
# # Seleção pela TAG

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())

navegador = webdriver.Chrome(service=servico)

navegador.get('https://www.hashtagtreinamentos.com/curso-power-bi')

titulo = navegador.find_element(By.TAG_NAME, 'h1').text
print(titulo)
# Out:
# Curso de Power BI Completo

# %% [markdown]
# # Selecionar pelo Partial Link Text ( ou LINK_TEXT)
# # partial_link_text é um pedaço de texto

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())

navegador = webdriver.Chrome(service=servico)

# navegador.get('https://www.hashtagtreinamentos.com/curso-power-bi')
# numero_whatsaap = navegador.find_elements(By.PARTIAL_LINK_TEXT,'Whatsapp').text
print(numero_whatsaap)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 11
#       8 navegador = webdriver.Chrome(service=servico)
#      10 navegador.get('https://www.hashtagtreinamentos.com/curso-power-bi')
# ---> 11 numero_whatsaap = navegador.find_elements(By.PARTIAL_LINK_TEXT,'Whatsapp').text
#      13 print(numero_whatsaap)
#
# AttributeError: 'list' object has no attribute 'text'

# %% [markdown]
# # selecionar pelo nome(name)
# # no campo do email, ele vai selecionar o email que eu digitar aqui no cód

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())

navegador = webdriver.Chrome(service=servico)
navegador.get('https://www.hashtagtreinamentos.com/curso-power-bi') 
navegador.find_element(By.NAME,'email').send_keys('joaovictor@gmail.com')
