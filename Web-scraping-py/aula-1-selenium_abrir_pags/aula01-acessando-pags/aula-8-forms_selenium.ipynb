# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())

navegador = webdriver.Chrome(service=servico)

navegador.get('http://127.0.0.1:8081/index.html')

# %%
# botão padrão (Clicar em botão)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())

navegador = webdriver.Chrome(service=servico)

navegador.get('http://127.0.0.1:8081/index.html')

navegador.find_element(By.XPATH,'/html/body/button').click()
alerta = navegador.switch_to.alert
# navegador.find_element
alert.accept()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 16
#      14 alerta = navegador.switch_to.alert
#      15 # navegador.find_element
# ---> 16 alert.accept()
#
# NameError: name 'alert' is not defined

# %% [markdown]
# ### Botão de Seleção estilo Checkbox
#
# **.text**
#
# **.get_attribute("value")**
#
# **.is_selected**
#
# **DICA**, esteja atento ao atributo "value" dos inputs

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())

navegador = webdriver.Chrome(service=servico)

navegador.get('http://127.0.0.1:8081/index.html')

navegador.find_element(By.XPATH,'/html/body/input[2]')
