# %% [markdown]
# # selecionar vários elementos de uma vez
# # vamos selecionar pelo "find_elements"
# # vamos clicar no item Blog do menu

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())

navegador = webdriver.Chrome(service=servico)

navegador.get('https://www.hashtagtreinamentos.com/')

lista_links = navegador.find_elements(By.TAG_NAME, 'a')

for link in lista_links:
    if 'blog' in link.text.lower():
        link.click()
        break
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[11], line 16
#      14 for link in lista_links:
#      15     if 'blog' in link.text.lower():
# ---> 16         link.click()
#      17         break
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:114, in WebElement.click(self)
#     107 def click(self) -> None:
#     108     """Clicks the element.
#     109
#     110     Example:
#     111         element = driver.find_element(By.ID, "foo")
#     112         element.click()
#     113     """
# --> 114     self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:508, in WebElement._execute(self, command, params)
#     506     params = {}
#     507 params["id"] = self._id
# --> 508 return self._parent.execute(command, params)
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:468, in WebDriver.execute(self, driver_command, params)
#     465 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     467 if response:
# --> 468     self.error_handler.check_response(response)
#     469     response["value"] = self._unwrap_value(response.get("value", None))
#     470     return response
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=148.0.7778.179); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#staleelementreferenceexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x11eb593+105d3]
# 	chromedriver!GetHandleVerifier [0x11eb6c4+10704]
# 	chromedriver!(No symbol) [0xff1ea0]
# 	chromedriver!(No symbol) [0x10043f2]
# 	chromedriver!(No symbol) [0x10034bc]
# 	chromedriver!(No symbol) [0xff93d9]
# 	chromedriver!(No symbol) [0xff7862]
# 	chromedriver!(No symbol) [0xffad4a]
# 	chromedriver!(No symbol) [0xffadd8]
# 	chromedriver!(No symbol) [0x103cf52]
# 	chromedriver!(No symbol) [0x10322ef]
# 	chromedriver!(No symbol) [0x105d77c]
# 	chromedriver!(No symbol) [0x1031da4]
# 	chromedriver!(No symbol) [0x105d944]
# 	chromedriver!(No symbol) [0x107a936]
# 	chromedriver!(No symbol) [0x105d516]
# 	chromedriver!(No symbol) [0x10308e9]
# 	chromedriver!(No symbol) [0x10316a4]
# 	chromedriver!GetHandleVerifier [0x1473014+298054]
# 	chromedriver!GetHandleVerifier [0x146e603+293643]
# 	chromedriver!GetHandleVerifier [0x148ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0x12054e8+2a528]
# 	chromedriver!GetHandleVerifier [0x120cd1d+31d5d]
# 	chromedriver!GetHandleVerifier [0x11f3e68+18ea8]
# 	chromedriver!GetHandleVerifier [0x11f4015+19055]
# 	chromedriver!GetHandleVerifier [0x11dd65f+269f]
# 	KERNEL32!BaseThreadInitThunk [0x771b5d49+19]
# 	ntdll!RtlInitializeExceptionChain [0x778dd83b+6b]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x778dd7c1+231]
