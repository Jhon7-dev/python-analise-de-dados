# %% [markdown]
# # acessando sites pelo link

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)
# navegador.get(r"C:\Users\55159\teste_sel\test.html")
navegador.get("https://github.com/Jhon7-dev")

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 navegador.get("https://github.com/Jhon7-dev")
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:488, in WebDriver.get(self, url)
#     475 def get(self, url: str) -> None:
#     476     """Navigate the browser to the specified URL.
#     477
#     478     The method does not return until the page is fully loaded (i.e. the
#    (...)    486         `driver.get("https://example.com")`
#     487     """
# --> 488     self.execute(Command.GET, {"url": url})
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:468, in WebDriver.execute(self, driver_command, params)
#     465 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     467 if response:
# --> 468     self.error_handler.check_response(response)
#     469     response["value"] = self._unwrap_value(response.get("value", None))
#     470     return response
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x39b593+105d3]
# 	chromedriver!GetHandleVerifier [0x39b6c4+10704]
# 	chromedriver!(No symbol) [0x1a1cde]
# 	chromedriver!(No symbol) [0x1dfb77]
# 	chromedriver!(No symbol) [0x20d636]
# 	chromedriver!(No symbol) [0x208861]
# 	chromedriver!(No symbol) [0x208241]
# 	chromedriver!(No symbol) [0x17502e]
# 	chromedriver!(No symbol) [0x1755ce]
# 	chromedriver!(No symbol) [0x175aad]
# 	chromedriver!GetHandleVerifier [0x623014+298054]
# 	chromedriver!GetHandleVerifier [0x61e603+293643]
# 	chromedriver!GetHandleVerifier [0x63ea05+2b3a45]
# 	chromedriver!GetHandleVerifier [0x3b54e8+2a528]
# 	chromedriver!GetHandleVerifier [0x3bcd1d+31d5d]
# 	chromedriver!(No symbol) [0x174ba6]
# 	chromedriver!(No symbol) [0x1741e0]
# 	chromedriver!GetHandleVerifier [0x7887af+3fd7ef]
# 	KERNEL32!BaseThreadInitThunk [0x771b5d49+19]
# 	ntdll!RtlInitializeExceptionChain [0x778dd83b+6b]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x778dd7c1+231]
# 	(No symbol) [(nil)]
