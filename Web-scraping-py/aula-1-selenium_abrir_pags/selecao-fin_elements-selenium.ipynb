# %% [markdown]
# SELEÇÃO DE VÁRIOS ELEMENTOS DE UMA VEZ

# %%
# VAMOS SELECIONAR PELO find_elements
# vamos clicar no item do blog do menu
# vai retornar uma lista de elementos

from selenium import webdriver
from selenium.webdriver.common.by import By
nav = webdriver.Chrome()
nav.get("https://www.clinicadacidade.com.br/centro-medico/sorocaba/")

# %%
# lista_elementos = nav.find_elements(By.CLASS_NAME, 'header__titulo')
# # print(len(lista_elementos))
# lista_elementos[4].click()
# for elemento in lista_elementos:
#     if "blog" in elemento.text.lower():
#           elemento.text.lower()
#           elemento.click()
#           break

# %% [markdown]
# Pegar informações do elemento

# %%
# link do wpp
text = nav.find_element(By.XPATH,'//*[@id="centro"]/section[5]/div/div/div[2]/div/div[2]/div/div/div/div[4]/a').text
print(text) 
# peguei so o texto do element ".text"
# para clicar é ".click()"
# para eu escrever no texto é "sendclick()"
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # link do wpp
# ----> 2 text = nav.find_element(By.XPATH,'//*[@id="centro"]/section[5]/div/div/div[2]/div/div[2]/div/div/div/div[4]/a').text
#       3 print(text)
#       4 # peguei so o texto do element ".text"
#       5 # para clicar é ".click()"
#       6 # para eu escrever no texto é "sendclick()"
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:868, in WebDriver.find_element(self, by, value)
#     865         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     866     return elements[0]
# --> 868 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:468, in WebDriver.execute(self, driver_command, params)
#     465 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     467 if response:
# --> 468     self.error_handler.check_response(response)
#     469     response["value"] = self._unwrap_value(response.get("value", None))
#     470     return response
#
# File c:\Users\55159\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=148.0.7778.179); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x7ff79d117de5+14895]
# 	chromedriver!GetHandleVerifier [0x7ff79d117e50+14900]
# 	chromedriver!(No symbol) [0x7ff79ce7d5ad]
# 	chromedriver!(No symbol) [0x7ff79ce68a92]
# 	chromedriver!(No symbol) [0x7ff79ce8ee6c]
# 	chromedriver!(No symbol) [0x7ff79cf071b0]
# 	chromedriver!(No symbol) [0x7ff79cf24172]
# 	chromedriver!(No symbol) [0x7ff79cec9df8]
# 	chromedriver!(No symbol) [0x7ff79cecace3]
# 	chromedriver!GetHandleVerifier [0x7ff79d42cc49+3296f9]
# 	chromedriver!GetHandleVerifier [0x7ff79d427375+323e25]
# 	chromedriver!GetHandleVerifier [0x7ff79d44bc82+348732]
# 	chromedriver!GetHandleVerifier [0x7ff79d136045+32af5]
# 	chromedriver!GetHandleVerifier [0x7ff79d13ecec+3b79c]
# 	chromedriver!GetHandleVerifier [0x7ff79d121bc4+1e674]
# 	chromedriver!GetHandleVerifier [0x7ff79d121d54+1e804]
# 	chromedriver!GetHandleVerifier [0x7ff79d1060e7+2b97]
# 	KERNEL32!BaseThreadInitThunk [0x7ffee15ae957+17]
# 	ntdll!RtlUserThreadStart [0x7ffee1f8427c+2c]

# %%
# para as imagens 
# aqui eu vou pegar o atributo
# link = nav.find_elements(By.XPATH,'//*[@id="centro"]/section[2]/div/div[2]/div[3]/a/img').get_attribute('src')
# print(link)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 # para as imagens
#       2 # aqui eu vou pegar o atributo
# ----> 3 link = nav.find_elements(By.XPATH,'//*[@id="centro"]/section[2]/div/div[2]/div[3]/a/img').get_attribute('src')
#       4 print(link)
#
# AttributeError: 'list' object has no attribute 'get_attribute'
