# %%
# - Vamos criar uma function com parâmetro

# Digamos que estamos criando um programa para categorizar os produtos de uma revendedora de bebidas.

# Cada produto tem um código. O tipo de produto é dado pelas 3 primeiras letras do código.

# Ex:<br>
# Vinho -> BEB12302<br>
# Cerveja -> BEB12043<br>
# Vodka -> BEB34501<br>

# Guaraná -> BSA11104<br>
# Coca -> BSA54301<br>
# Sprite -> BSA34012<br>
# Água -> BSA09871<br>

# Repare que bebidas não alcóolicas começam com BSA e bebidas alcoolicas começam com BEB.

# Crie um programa que analise uma lista de produtos e envie instruções para a equipe de estoque dizendo quais produtos devem ser enviados para a área de bebidas alcóolicas.

# %%
produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']

def produtos_Alcoolicos(produtos):
     for produto in produtos:
          if 'BEB' in produto:
               print('Enviando produto',produto,' para o setor ALCOÓLICO!')
          elif 'BSA' in produto:
               print('Enviando produto',produto, 'para o setor NÃO ALCOÓLICO!')
          else:
               print('Enviando produto',produto, 'para o setor terciario')
print(produtos_Alcoolicos(produtos))
# Out:
# Enviando produto beb46275 para o setor terciario
# Enviando produto TFA23962 para o setor terciario
# Enviando produto TFA64715 para o setor terciario
# Enviando produto TFA69555 para o setor terciario
# Enviando produto TFA56743 para o setor terciario
# Enviando produto BSA45510 para o setor NÃO ALCOÓLICO!
# Enviando produto TFA44968 para o setor terciario
# Enviando produto CAR75448 para o setor terciario
# Enviando produto CAR23596 para o setor terciario
# Enviando produto CAR13490 para o setor terciario
# Enviando produto BEB21365  para o setor ALCOÓLICO!
# Enviando produto BEB31623  para o setor ALCOÓLICO!
# Enviando produto BSA62419 para o setor NÃO ALCOÓLICO!
# Enviando produto BEB73344  para o setor ALCOÓLICO!
# Enviando produto TFA20079 para o setor terciario
# Enviando produto BEB80694  para o setor ALCOÓLICO!
# Enviando produto BSA11769 para o setor NÃO ALCOÓLICO!
# Enviando produto BEB19495  para o setor ALCOÓLICO!
# Enviando produto TFA14792 para o setor terciario
# Enviando produto TFA78043 para o setor terciario
# Enviando produto BSA33484 para o setor NÃO ALCOÓLICO!
# Enviando produto BEB97471  para o setor ALCOÓLICO!
# Enviando produto BEB62362  para o setor ALCOÓLICO!
# Enviando produto TFA27311 para o setor terciario
# Enviando produto TFA17715 para o setor terciario
# Enviando produto BEB85146  para o setor ALCOÓLICO!
# Enviando produto BEB48898  para o setor ALCOÓLICO!
# Enviando produto BEB79496  para o setor ALCOÓLICO!
# Enviando produto CAR38417 para o setor terciario
# Enviando produto TFA19947 para o setor terciario
# Enviando produto TFA58799 para o setor terciario
# Enviando produto CAR94811 para o setor terciario
# Enviando produto BSA59251 para o setor NÃO ALCOÓLICO!
# Enviando produto BEB15385  para o setor ALCOÓLICO!
# Enviando produto BEB24213  para o setor ALCOÓLICO!
# Enviando produto BEB56262  para o setor ALCOÓLICO!
# Enviando produto BSA96915 para o setor NÃO ALCOÓLICO!
# Enviando produto CAR53454 para o setor terciario
# Enviando produto BEB75073  para o setor ALCOÓLICO!
# None
