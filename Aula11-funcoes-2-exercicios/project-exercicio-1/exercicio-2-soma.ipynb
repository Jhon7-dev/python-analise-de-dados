# %%
# - Só para mostrar o funcionamento, vamos criar uma função de soma

# %%
def soma(num1,num2,num3):
     return print('A soma dos Números são:',num1+num2+num3)
soma(1,10,3)
def multiplicacao(num1,num2,num3):
     return print('A multiplicação é:',num1*num2*num3)
multiplicacao(10,20,30)
def divisao(num1,num2):
     return print('A divisão é:',num1/num2)
divisao(20,100)
# Out:
# A soma dos Números são: 14
# A multiplicação é: 6000
# A divisão é: 0.2
