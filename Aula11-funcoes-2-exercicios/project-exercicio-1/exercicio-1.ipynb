# %% [markdown]
# vamos criar uma função de cadastro de um Produto. Essa função deve garantir que o produto cadastrado está em letra minúscula.

# %%
def cadastrarProduto():
     
     lista_produtos = []
     produto=input("Digite o produto: ")
     lista_produtos.append(produto)
     return print('produto: ', lista_produtos.title() , ' cadastrado com sucesso! ')
print(cadastrarProduto())
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 8
#       6      lista_produtos.append(produto)
#       7      return print('produto: ', lista_produtos.title() , ' cadastrado com sucesso! ')
# ----> 8 print(cadastrarProduto())
#
# Cell In[1], line 6, in cadastrarProduto()
#       3 for lista in lista_produtos:
#       5      produto=input("Digite o produto: ")
# ----> 6 lista_produtos.append(produto)
#       7 return print('produto: ', lista_produtos.title() , ' cadastrado com sucesso! ')
#
# UnboundLocalError: cannot access local variable 'produto' where it is not associated with a value
