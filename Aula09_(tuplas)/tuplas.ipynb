# %% [markdown]
# ## Tuplas
# # estrutura:
# tupla = (valor,valor,valor...)
#
# # diferença
# parece uma lista, mas é imutável.
#
# # vantagens:
# eficiente em termos de performace

# %%
vendas = ('joao','27/08/2003','20/09/2025',4000,'Estagiário')
print (vendas)

#acessando o valor de uma tupla

nome = vendas[0]
data_contratacao = vendas[1]
data_nascimento = vendas[2]
salario = vendas[3]
cargo = vendas[4]
# se eu tenho 5 vlaores na tuplas, eu tenho que ter 5 variáveis
nome,data_contratacao,data_nascimento,salario,cargo = vendas
print(nome)
print(salario)
# Out:
# ('joao', '27/08/2003', '20/09/2025', 4000, 'Estagiário')
# joao
# 4000

# %%
vendas = [100,200,300,150]
funcionarios = ['joao','lira', 'ana','maria','jair']
for i, venda in enumerate(vendas):
     print('{} vende {} unidades'.format(funcionarios[i],venda))
# Out:
# joao vende 100 unidades
# lira vende 200 unidades
# ana vende 300 unidades
# maria vende 150 unidades
