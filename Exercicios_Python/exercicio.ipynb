# %%
import sys
num = int(input("digite o número: "))
while num != 1:
 def collatz(num):
     if num % 2 == 0:
         return  resposta = num /2
         print(resposta)
     elif num % 2 == 1:
          resposta = 3 * (num + 1)
          return resposta
          print(resposta)
     else:
          sys.exit()
          print("encerrado")
