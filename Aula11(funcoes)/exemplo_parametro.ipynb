# %%
# upper() -> não tem parâmetros
# sort() -> apenas parâmetros keyword
# extend(lista) -> 1 parametro obrigatório
def eh_da_categoria(bebida, cod_categoria):
     bebida = bebida.upper()
     if cod_categoria in bebida:
          return True
     else:
          return False

produtos = ['BEB46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']
# texto para upper
cod_produto = 'beb12304'
print(cod_produto.upper())
# lista para sort e extend
vendas_ano = [100,200,50,90,240,300,55,10,789,60]
print('Vendas anuais ', vendas_ano)
# vendas_de_novembro_e_dezembro
vendas_novdez = [500,1555]
print('venda de novembro e dezembro ', vendas_novdez)
# pega a lista e deixa em ordem crescente
vendas_ano.sort() 
# agora se eu quiser adicionar mais as vendas de nov e dez 
vendas_ano.extend(vendas_novdez)
print(vendas_ano)

# if eh_da_categoria():
# Out:
# BEB12304
# Vendas anuais  [100, 200, 50, 90, 240, 300, 55, 10, 789, 60]
# venda de novembro e dezembro  [500, 1555]
# [10, 50, 55, 60, 90, 100, 200, 240, 300, 789, 500, 1555]
