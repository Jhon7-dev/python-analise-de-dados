# %% [markdown]
# # Funções
# ### o que é?
# as funções são miniprogramas ou blocos de codigo que tem 1 único propósito, fazem uma ação específica
#
# ### Estrutura básica
#
# def nome_funcao():
#      faça alguma coisa
#      faça outra coisa
#      retrun valor_final

# %%
# def nome_funcao():
#      faca alguma coisa
#      faca  outra coisa
#      return valor_final

# %%
def hello():
     print("HOWDY!")
     print("HOWDY!!!")
     print("HELLO")
hello()
# hello()
# hello()
# Out:
# HOWDY!
# HOWDY!!!
# HELLO

# %%
# criar uma funçãao de cadastro de um Produto. Essa função deve garantir que o produto cadastrado está em letra minúscula

def cadastrar_produto():
     produto = input('digite o nome do produto que deseja cadastrar: ')
     produto = produto.casefold()
     print('produto {} cadastrado com sucesso'.format(produto))
     return produto

# %%
cadastrar_produto()
# Out:
# produto feijão cadastrado com sucesso
# 'feijão'

# %%
variavel_produto = cadastrar_produto()
print(variavel_produto)
#  variavel_produto porque se eu colocar produto da erro por que produto so existe dentro da função
# Out:
# produto arroz cadastrado com sucesso
# arroz

# %%
for i in range(3):
          cadastrar_produto()
# Out:
# produto feijão cadastrado com sucesso
# produto arroz cadastrado com sucesso
# produto macarrão cadastrado com sucesso

# %% [markdown]
# ## instruções def com parâmetros
#
# a definição da funçaõ hello() nesse programa contém  um parâmetro chamado *name*. Um *parâmetro* é uma variável em que um argumento é armazenado quando ua função é chamada. Na primeira vez que a função *hello* é chamada, isso é feito com o argumento 'alice'.
# *obs*: o valor armazenado em um parâmetro é esquecido quando a função retorna. Exemplo se adicionarmos print(name) depois de hello(bob), um nameError será gerado pelo progrma, pois não há nenhuyma variável chamada *name*.

# %%
#def minha_funcai(parametro1,parametro3,parametro3):
     #return parametro1 + parametro2 + parametro3

# %%
def minha_soma(num1,num2,num3):
     return num1 + num2 +num3
soma = minha_soma (10,20,30)
print(soma)
# Out:
# 60

# %%
def hello(name):
     print('hello ' + name)
hello("joao")
hello("manu")
# Out:
# hello joao
# hello manu

# %% [markdown]
# ## valores de retorno e instruções return
# ## o valor de uma instrução *return* é constituída das partes:
# * a palavra-chave return
# * o valor ou a espressão que a função deve retornar.

# %%
import random 
def fazer_perguntas(number):
     if number == 1:
          return "certo!"
     elif number == 2:
          return "tente denovo!"
     elif number == 3:
          return 'yes'
     elif number == 4:
          return 'repita, tenta outra vez!'
     elif number == 5:
          return 'tente de novo!'
# r = random.randint(1,6)
# fortune = fazer_perguntas(r)
print(fazer_perguntas(random.randint(1,5)))
# Out:
# yes
