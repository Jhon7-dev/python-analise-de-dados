# %% [markdown]
# comece com uma cópia de seu programa do exercicio anterior. Escreva uma função chamada make_great() que modifique a lista de mágicos acrescentando a expressão "O Grande" ao nome de cada mágico. Chame show_magicians() para ver se a lista foi realmente modificada

# %%
magicos = ['arman','luther','tubinho','stanco','leo'] 
grandes_magicos = []
def show_magicos(magicos):
          for magico in magicos:
           print('Mágico', magico.title())
show_magicos(magicos)

def make_great(magicos):
     for grandes_magicos in magicos:
          print('O Grande Mágico', grandes_magicos.title() )
          
make_great(magicos)
# Out:
# Mágico Arman
# Mágico Luther
# Mágico Tubinho
# Mágico Stanco
# Mágico Leo
# O Grande Mágico Arman
# O Grande Mágico Luther
# O Grande Mágico Tubinho
# O Grande Mágico Stanco
# O Grande Mágico Leo
