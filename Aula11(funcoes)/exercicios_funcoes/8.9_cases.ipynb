# %% [markdown]
# crie uma lista de nomes de mágicos.Passe a lista para um funçãp chamada show-magician() que exiba o nome de cada magico

# %%
magicos = ['arman','luther','tubinho','stanco','leo'] 
def show_magicos(magicos):
     for magico in magicos:
          print(magicos)
          break 
show_magicos(magicos)
# Out:
# ['arman', 'luther', 'tubinho', 'stanco', 'leo']
