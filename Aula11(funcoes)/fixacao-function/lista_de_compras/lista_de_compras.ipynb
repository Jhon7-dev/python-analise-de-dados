# %%
lista_compras = []

while True:
     print('----- Lista De Compras -----')
     print('1 - Adicionar Item')
     print('2 - Remover Item')
     print('3 - Ver Lista')
     print('4 - Sair')
     opcao = input('Digite um Opção : ')
     
     if opcao == '1':
          def cadastrar_produto():
               lista = input(' digite o que você deseja adicionar ao carrinho')
               lista.append(lista_compras)
               return lista_compras
     cadastrar_produto(lista_compras)
# Out:
# ----- Lista De Compras -----
# 1 - Adicionar Item
# 2 - Remover Item
# 3 - Ver Lista
# 4 - Sair
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 16
#      14           lista.append(lista_compras)
#      15           return lista_compras
# ---> 16 cadastrar_produto(lista_compras)
#
# TypeError: cadastrar_produto() takes 0 positional arguments but 1 was given

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cadastrar_produto()
#
# NameError: name 'cadastrar_produto' is not defined
