# %%
# EXERCÍCIO — Sistema de Análise Financeira de Clientes e Vendas

# Uma empresa de e-commerce deseja criar um pequeno sistema de análise financeira.

# O objetivo do sistema é:

# identificar clientes inadimplentes
# calcular o percentual de prejuízo causado por inadimplência
# descobrir quanto a empresa deixou de receber

# Você deverá criar funções que trabalhem com:

# listas
# tuplas
# dicionários
# acumuladores
# filtros condicionais
# porcentagens

# REGRAS DE NEGÓCIO

# A empresa considera um cliente inadimplente quando:

# ele deve MAIS de R$ 1.000
# E está devendo há MAIS de 20 dias

# %%
clientes = [
('462.286.561-65', 14405, 24),
('251.569.170-81', 16027, 1),
('297.681.579-21', 8177, 28),
('790.223.154-40', 9585, 10),
('810.442.219-10', 18826, 29),
('419.210.299-79', 11421, 15),
('908.507.760-43', 12445, 24),
('911.238.364-17', 1345, 4),
('131.115.339-28', 11625, 8),
('204.169.467-27', 5364, 22),
('470.806.376-11', 932, 29),
('938.608.980-69', 13809, 19),
('554.684.165-26', 11227, 2),
('119.225.846-34', 4475, 9),
('358.890.858-95', 13932, 20),
('786.547.940-70', 17048, 25),
('468.487.741-94', 2902, 8),
('540.685.100-32', 5806, 21),
('379.729.796-80', 7622, 24),
('980.173.363-94', 13167, 24)
]
vendas = {
'VE0001': (9868, 'Concluído'),
'VE0002': (9642, 'Concluído'),
'VE0003': (6007, 'Concluído'),
'VE0004': (15562, 'Concluído'),
'VE0005': (18752, 'Concluído'),
'VE0006': (16358, 'Concluído'),
'VE0007': (17045, 'Concluído'),
'VE0008': (12230, 'Concluído'),
'VE0009': (6747, 'Concluído'),
'VE0010': (15114, 'Concluído'),
'VE0011': (12497, 'Concluído'),
'VE0012': (6001, 'Concluído'),
'VE0013': (16227, 'Cancelado'),
'VE0014': (16150, 'Concluído'),
'VE0015': (17705, 'Concluído'),
'VE0016': (9978, 'Concluído'),
'VE0017': (4266, 'Concluído'),
'VE0018': (11531, 'Concluído'),
'VE0019': (10352, 'Cancelado'),
'VE0020': (16544, 'Concluído')
}
def listar_inadimplentes(lista_clientes):
     lista_inadimplentes_clientes = [] 
     for cpf,valor,dias in lista_clientes:
          if valor > 1000 and dias> 20:
             lista_inadimplentes_clientes.append(cpf)
     return lista_inadimplentes_clientes
print('Os clientes são ', clientes)
print('total de clientes ao todo são ', len(clientes))
print('Os clientes Inadimplentes são os seguintes',listar_inadimplentes(clientes))
print('O número de clientes inadimplentes é ', len(listar_inadimplentes(clientes)))

def valor_total_de_inadimplentes(valor):
     soma = 0
     for cpf,valor,dias in listar_inadimplentes:
          soma += valor
     return soma
print(valor_total_de_inadimplentes())
# Out:
# Os clientes são  [('462.286.561-65', 14405, 24), ('251.569.170-81', 16027, 1), ('297.681.579-21', 8177, 28), ('790.223.154-40', 9585, 10), ('810.442.219-10', 18826, 29), ('419.210.299-79', 11421, 15), ('908.507.760-43', 12445, 24), ('911.238.364-17', 1345, 4), ('131.115.339-28', 11625, 8), ('204.169.467-27', 5364, 22), ('470.806.376-11', 932, 29), ('938.608.980-69', 13809, 19), ('554.684.165-26', 11227, 2), ('119.225.846-34', 4475, 9), ('358.890.858-95', 13932, 20), ('786.547.940-70', 17048, 25), ('468.487.741-94', 2902, 8), ('540.685.100-32', 5806, 21), ('379.729.796-80', 7622, 24), ('980.173.363-94', 13167, 24)]
# total de clientes ao todo são  20
# Os clientes Inadimplentes são os seguintes ['462.286.561-65', '297.681.579-21', '810.442.219-10', '908.507.760-43', '204.169.467-27', '786.547.940-70', '540.685.100-32', '379.729.796-80', '980.173.363-94']
# O número de clientes inadimplentes é  9
# ---------------------------------------------------------------------------
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       4           if valor > 1000 and dias> 20:
#       5              lista_inadimplentes_clientes.append = cpf
# ----> 6 print(listar_inadimplentes(clientes))
#
# NameError: name 'clientes' is not defined
