# %%
def eh_da_categoria(bebida, cod_categoria):
     bebida = bebida.upper()
     if cod_categoria in bebida:
          return True
     else:
          return False

produtos = ['BEB46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']
# BEB
# BSA
# TFA
# CAR

for produto in produtos:
     if eh_da_categoria(produto, 'BEB'):
          print('Enviar {} produto para setor de bebidas alcoólicas'.format(produto))
     elif eh_da_categoria (produto, 'BSA'):
          print('Enviar {} para setor de bebidas não alcoólicas'.format(produto))
# Out:
# Enviar BEB46275 produto para setor de bebidas alcoólicas
# Enviar BSA45510 para setor de bebidas não alcoólicas
# Enviar BEB21365 produto para setor de bebidas alcoólicas
# Enviar BEB31623 produto para setor de bebidas alcoólicas
# Enviar BSA62419 para setor de bebidas não alcoólicas
# Enviar BEB73344 produto para setor de bebidas alcoólicas
# Enviar BEB80694 produto para setor de bebidas alcoólicas
# Enviar BSA11769 para setor de bebidas não alcoólicas
# Enviar BEB19495 produto para setor de bebidas alcoólicas
# Enviar BSA33484 para setor de bebidas não alcoólicas
# Enviar BEB97471 produto para setor de bebidas alcoólicas
# Enviar BEB62362 produto para setor de bebidas alcoólicas
# Enviar BEB85146 produto para setor de bebidas alcoólicas
# Enviar BEB48898 produto para setor de bebidas alcoólicas
# Enviar BEB79496 produto para setor de bebidas alcoólicas
# Enviar BSA59251 para setor de bebidas não alcoólicas
# Enviar BEB15385 produto para setor de bebidas alcoólicas
# Enviar BEB24213 produto para setor de bebidas alcoólicas
# Enviar BEB56262 produto para setor de bebidas alcoólicas
# Enviar BSA96915 para setor de bebidas não alcoólicas
# Enviar BEB75073 produto para setor de bebidas alcoólicas
