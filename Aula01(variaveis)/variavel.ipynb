# %%
qtde_vendas = 1500
nome ='joao'


print(qtde_vendas)
print(nome)

print('joao')
print('victor ')
print("gomes")
# aspas simples e duplas são equivalentes
# Out:
# 1500
# joao
# joao
# victor
# gomes

# %%
print('joao')
print('victor ')
print("gomes")
# Out:
# joao
# victor
# gomes

# %%
print("Curso","python progressivo")
print("curso:\n'python'\n progressivo")
# Out:
# Curso python progressivo
# curso:
# 'python'
#  progressivo

# %%
#Crie um programa que exiba na tela seu nome completo, sua cidade, estado e data de nascimento.
nome = 'João Victor Gomes de Souza'
cidade = 'Sorocaba'
estado = 'São paulo'
dataNascimento = 27,8,2003
idade = 22
print("Nome: ", nome)
print("Cidade: ", cidade)
print("Estado: ", estado)
print("Idade: ", idade)
print("Data de Nascimento: ", dataNascimento)
# Out:
# Nome:  João Victor Gomes de Souza
# Cidade:  Sorocaba
# Estado:  São paulo
# Idade:  22
# Data de Nascimento:  (27, 8, 2003)

# %%
#Crie um programa que exiba na tela o texto 'A melhor banda do mundo é [nome da banda] e a melhor música é [nome da música]'.

#O nome da banda e o nome da música devem estar declarados em duas variáveis diferentes.

nomeDaBanda = "Guns `n Roses"
musicaDaBanda = "Sweet child of mine"

print("a melhor banda do mundo é ", nomeDaBanda, " e a melhor música é ", musicaDaBanda)
# Out:
# a melhor banda do mundo é  Guns `n Roses  e a melhor música é  Sweet child of mine

# %%
faturamento = 1000
type(faturamento)
# Out:
# int

# %%
faturamento = 1000.00
type(faturamento)
# Out:
# float

# %%
faturamento='faturamento'
type(faturamento)
# Out:
# str

# %%
# para atribuir valor a um  variável poder ser utilizado o comando input(), que funciona como scanner ( solicita ao usuário o valor a ser atribuido à variável)

nome = input ("entre com o seu nome: ")
nome
# Out:
# 'joao'

# %%
# o comando input(), sempre retornará uma String. Nesse caso, papra retronar dados do tipo inteiro ou float,é preciso converter o tipo do valor lido. 
# para isso, utiliza-se o int(String) para converter o tipo inteiro, ou float(string) para converter o tipo float
 
num = int(input("Entre com sua idade : "))
num
# Out:
# 12

# %%
altura = float(input("Digite sua altura: "))
altura
# Out:
# 1.45

# %%
#Escreva um programa que solicite uma frase ao usuário e escreva a frase toda em maiúscula e sem espaços em branco.

frase = input("Digite um frase: ")
frase
# Out:
# 'ola,mundo'

# %%
numeroUm = int(input("Digite o primeiro número"))
numeroDois = int(input("Digite o segundo  número"))
soma = numeroUm + numeroDois
print(soma)
# Out:
# 7
